# %% [markdown]
# # WebScraping

# %% [markdown]
# ---
# * Author:  [Yuttapong Mahasittiwat](mailto:khala1391@gmail.com)
# * Technologist | Data Modeler | Data Analyst
# * [YouTube](https://www.youtube.com/khala1391)
# * [LinkedIn](https://www.linkedin.com/in/yuttapong-m/)
# * [Tableau](https://public.tableau.com/app/profile/yuttapong.m/vizzes)
# ---

# %% [markdown]
# ref: [WS CubeTech youtube channel](https://www.youtube.com/watch?v=UabBGhnVqSo&list=PLc20sA5NNOvrsn3a78ewy2VTCXVV47NB4&index=1&t=0s)

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2024-10-20 20:41:04.090947

# %% [markdown]
# ## import library

# %%
from urllib.request import urlopen # option#1
import requests  # option#2

import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ## set up BeautifulSoup

# %%
## option#1: urllib library
url="https://webscraper.io/test-sites/e-commerce/allinone"
html = urlopen(url)
soup = BeautifulSoup(html.read(), 'lxml')  # or 'html.parser'

## option#2 request library
# url="https://webscraper.io/test-sites/e-commerce/allinone"
# r = requests.get(url)
# soup = BeautifulSoup(r.text, "lxml")


print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Google Tag Manager -->
# <script nonce="Ix7yhYl52G3NNtrDIPrCBmqG7DtP2L7A">(function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');</script>
# <!-- End Google Tag Manager -->
# <title>Allinone | Web Scraper Test Sites</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# ...

# %%
html.*?
# Out:
# html.__abstractmethods__
# html.__class__
# html.__del__
# html.__delattr__
# html.__dict__
# html.__dir__
# html.__doc__
# html.__enter__
# html.__eq__
# html.__exit__
# html.__format__
# html.__ge__
# html.__getattribute__
# html.__getstate__
# html.__gt__
# html.__hash__
# html.__init__
# html.__init_subclass__
# html.__iter__
# html.__le__
# html.__lt__
# html.__module__
# html.__ne__
# html.__new__
# html.__next__
# html.__reduce__
# html.__reduce_ex__
# html.__repr__
# html.__setattr__
# html.__sizeof__
# html.__str__
# html.__subclasshook__
# html.begin
# html.chunk_left
# html.chunked
# html.close
# html.closed
# html.code
# html.debuglevel
# html.detach
# html.fileno
# html.flush
# html.fp
# html.getcode
# html.getheader
# html.getheaders
# html.geturl
# html.headers
# html.info
# html.isatty
# html.isclosed
# html.length
# html.msg
# html.peek
# html.read
# html.read1
# html.readable
# html.readinto
# html.readinto1
# html.readline
# html.readlines
# html.reason
# ...

# %%
title = soup.find_all("a", class_= "title")
title = [i.text for i in title]
# print(title)

description = soup.find_all("p", class_="description card-text")
description = [i.text for i in description]
print(description)
# Out:
# ['7" screen, Android', 'Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2', '7" screen, Android, 16GB', '7", 8GB, Wi-Fi, Android 4.2, White', 'Black, 7", 1.6GHz Dual-Core, 8GB, Android 4.4', 'IPS, Dual-Core 1.2GHz, 8GB, Android 4.3', '7" screen, Android, 8GB', '6" screen, wifi', '7", 8GB, Wi-Fi, Android 4.2, Yellow', 'Blue, 8" IPS, Quad-Core 1.3GHz, 16GB, Android 4.2', 'White, 7", Atom 1.2GHz, 8GB, Android 4.4', 'Blue, 7" IPS, Quad-Core 1.3GHz, 8GB, 3G, Android 4.2', 'Silver, 7" IPS, Quad-Core 1.2Ghz, 16GB, 3G, Android 4.2', 'LTE (SM-T235), Quad-Core 1.2GHz, 8GB, Black', '16GB, White', 'White, 10.1" IPS, 1.6GHz, 2GB, 16GB, Android 4.2', '10.1", 3G, Android 4.0, Garnet Red', '12.2", 32GB, WiFi, Android 4.4, White', 'Wi-Fi + Cellular, 32GB, Silver', '10.1", 32GB, Black', 'Wi-Fi, 64GB, Silver']

# %%
# print(soup.div)
# print(soup.div.ul)
# print(soup.div.ul.li.a)
# print(soup.div.ul.a)   # can skip

# print()
# print(soup.div.a)   # can skip, but result different
# print()

# print()
# print(soup.div.a)   # can skip, but result different
# print()
# Out:
# Web Scraper

# %%
# print(soup.header)
# tag_header =  soup.header
# print(tag_header.attrs)
# print(tag_header.attrs['role'])
# print(tag_header.attrs['class'])
# print(tag_header.attrs['class'][1])

content = soup.div.p.string
print(content)

# tag = soup.div.a
# print(tag.attrs)

# %%
tag = soup.header.div.a.button.span
print(tag.string)
# Out:
# Toggle navigation
